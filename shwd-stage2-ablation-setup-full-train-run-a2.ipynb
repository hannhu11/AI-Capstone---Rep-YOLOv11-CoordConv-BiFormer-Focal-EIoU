# %% [markdown]
# # SHWD Stage 2 Ablation Setup
#
# This notebook initializes Stage 2 (Custom Module Ablation Study) for Safety Helmet Detection.
# It automatically detects Kaggle input datasets & notebook outputs, extracts Top-2 weights (`yolo11s_best.pt`, `yolov8s_best.pt`), converts VOC2028 to YOLO format, and smoke-tests custom modules (`CoordConv`, `RepConv`, `BiFormer`, `Focal-EIoU`).
#
# **Mounted Kaggle Inputs Handled:**
# - Dataset: `VOC2028` (`/kaggle/input/datasets/hannhu4002/voc2028`)
# - Dataset: `shwd-benchmark-code` (`/kaggle/input/datasets/hannhu4002/shwd-benchmark-code`)
# - Notebook Output: `Structural Re-parameterized YOLO Architecture1`
# - Notebook Output: `Structural Re-parameterized YOLO Architecture2`
# - Notebook Output: `SHWD_Baseline_Consolidated_2` (contains `SHWD_Compact_Outputs.zip`)

# %% [markdown]
# ## Stage 2 Execution Settings
#
# This block is intentionally similar to the Stage 1 notebook. For normal use, run setup first, then toggle the ablation runs you want.
#
# Important distinction:
# - Stage 1 used stock Ultralytics models, so `RUN_FULL_TRAINING=True` could safely launch all baselines.
# - Stage 2 changes architecture/loss. A0 is immediately runnable. A1 can be run as an Albumentations offline-augmented dataset experiment. A2-A6 are controlled custom-module experiments and must be integrated carefully before full 100-epoch runs.

# %%
# Step 0: Stage 2 Settings / Toggles
from pathlib import Path

# Master switch. Keep False while validating each ablation. When True, cells use STAGE2_FULL_EPOCHS.
RUN_STAGE2_FULL = True

# Setup checks
RUN_SETUP_CONVERT = True
RUN_MODULE_SMOKE_TEST = True

# Runnable Stage 2 experiments in this notebook
RUN_A0_CONTROL_EVAL = False          # Re-evaluate yolo11s_best.pt and yolov8s_best.pt as controls.
RUN_A1_BUILD_AUG_DATASET = True    # Build offline Albumentations hard-case train set.
RUN_A1_HARDCASE_AUG_TRAIN = False   # Fine-tune top-2 weights on the A1 augmented dataset.

# Stage 2 custom-module switches. These are intentionally guarded until a custom trainer/model YAML is patched.
RUN_A2_COORDCONV = True
RUN_A3_REPCONV_REPC3 = False
RUN_A4_FOCAL_EIOU_ALPHA_FOCAL = False
RUN_A5_BIFORMER = False
RUN_A6_FULL_FUSION = False

# Training settings
STAGE2_SMOKE_EPOCHS = 3
STAGE2_FULL_EPOCHS = 100
STAGE2_IMGSZ = 640
STAGE2_BATCH = 16
STAGE2_DEVICE = '0,1'       # train on Dual T4
STAGE2_EVAL_DEVICE = '0'    # val/predict/export on one GPU to avoid DDP predict issues
STAGE2_WORKERS = 4
STAGE2_PATIENCE = 50
STAGE2_SEED = 3407

# A1 hard-case offline augmentation controls. None means all train images; use a small number for smoke tests.
A1_AUGMENT_LIMIT = 256 if not RUN_STAGE2_FULL else None
A1_JPEG_QUALITY = 92

# Top-2 selected after Stage 1
STAGE2_BACKBONES = ['yolo11s', 'yolov8s']

print('RUN_STAGE2_FULL =', RUN_STAGE2_FULL)
print('Runnable now: A0 control eval =', RUN_A0_CONTROL_EVAL, '| A1 build/train =', RUN_A1_BUILD_AUG_DATASET, RUN_A1_HARDCASE_AUG_TRAIN)
print('Custom guarded toggles: A2=', RUN_A2_COORDCONV, 'A3=', RUN_A3_REPCONV_REPC3, 'A4=', RUN_A4_FOCAL_EIOU_ALPHA_FOCAL, 'A5=', RUN_A5_BIFORMER, 'A6=', RUN_A6_FULL_FUSION)
print('Epochs selected =', STAGE2_FULL_EPOCHS if RUN_STAGE2_FULL else STAGE2_SMOKE_EPOCHS)
# Out:
# RUN_STAGE2_FULL = True
# Runnable now: A0 control eval = False | A1 build/train = True False
# Custom guarded toggles: A2= True A3= False A4= False A5= False A6= False
# Epochs selected = 100

# %%
# Step 1: Install Dependencies
from pathlib import Path
import sys
import subprocess

def find_file(name):
    candidates = [Path.cwd() / name, Path('/kaggle/working') / name]
    if Path('/kaggle/input').exists():
        candidates.extend(Path('/kaggle/input').rglob(name))
    return next((p for p in candidates if p.exists()), None)

req_path = find_file('requirements_kaggle.txt')
if req_path:
    print('Installing from:', req_path)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-U', '-r', str(req_path)], check=True)
else:
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-U', 'ultralytics', 'onnx', 'onnxruntime-gpu', 'pandas', 'albumentations', 'opencv-python-headless'], check=True)
# Out:
# Installing from: /kaggle/input/datasets/hannhu4002/shwd-benchmark-code/requirements_kaggle.txt
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.8/249.8 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 104.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 MB 30.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# ydata-profiling 4.18.4 requires pandas!=1.4.0,<3.0,>1.5, but you have pandas 3.0.5 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.5 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.5 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# db-dtypes 1.5.1 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.5 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.5 which is incompatible.

# %%
# Step 2: Automatic Flexible Path & Weight Resolution
from pathlib import Path
import os
import shutil
import zipfile
import subprocess
import sys

def find_dir_by_markers(dirname, required_children):
    roots = [Path('/kaggle/input'), Path('/kaggle/working'), Path.cwd()]
    for root in roots:
        if not root.exists():
            continue
        for p in root.rglob(dirname):
            if p.is_dir() and all((p / child).exists() for child in required_children):
                return p
    return None

def find_file_anywhere(name):
    roots = [Path.cwd(), Path('/kaggle/working'), Path('/kaggle/input')]
    for root in roots:
        if not root.exists():
            continue
        direct = root / name
        if direct.exists():
            return direct
        matches = list(root.rglob(name))
        if matches:
            return matches[0]
    return None

# 1. Locate VOC2028 Dataset Root
DATASET_ROOT = find_dir_by_markers('VOC2028', ['Annotations', 'JPEGImages', 'ImageSets'])
print('📌 DATASET_ROOT =', DATASET_ROOT)

# 2. Resolve Compact Artifacts & Top-2 Model Weights
EXTRACT_DIR = Path('/kaggle/working/extracted_compact')
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

# Look for SHWD_Compact_Outputs.zip inside SHWD_Baseline_Consolidated_2
compact_zip = find_file_anywhere('SHWD_Compact_Outputs.zip')
if compact_zip and compact_zip.exists():
    print(f'📦 Found Compact ZIP at: {compact_zip}. Extracting...')
    with zipfile.ZipFile(compact_zip, 'r') as zip_ref:
        zip_ref.extractall(EXTRACT_DIR)
    print(f'✅ Extracted artifacts to: {EXTRACT_DIR}')

# Locate Compact Root (either extracted zip or directory)
COMPACT_ROOT = find_dir_by_markers('SHWD_Compact_Outputs', ['weights', 'master_benchmark_results.csv'])
if COMPACT_ROOT is None and (EXTRACT_DIR / 'master_benchmark_results.csv').exists():
    COMPACT_ROOT = EXTRACT_DIR
print('📌 COMPACT_ROOT =', COMPACT_ROOT)

# 3. Resolve Support Scripts
SCRIPT_PATH = find_file_anywhere('kaggle_shwd_baseline.py')
MODULE_PATH = find_file_anywhere('custom_ablation_modules.py')
AUG_PATH = find_file_anywhere('albumentations_hardcase_policy.py')

print('📌 SCRIPT_PATH =', SCRIPT_PATH)
print('📌 MODULE_PATH =', MODULE_PATH)
print('📌 AUG_PATH =', AUG_PATH)

# Verify code scripts & dataset exist
if not DATASET_ROOT or not SCRIPT_PATH or not MODULE_PATH:
    raise FileNotFoundError('Missing required VOC2028 dataset or python scripts! Check input attachments.')

# 4. Flexible Top-2 Model Weights Lookup (Zip Extraction or Raw Run Outputs)
TOP2_WEIGHTS = {}

# Try 1: Look in COMPACT_ROOT weights
if COMPACT_ROOT and (COMPACT_ROOT / 'weights').exists():
    w_dir = COMPACT_ROOT / 'weights'
    y11 = list(w_dir.glob('*yolo11s*best*.pt'))
    y8 = list(w_dir.glob('*yolov8s*best*.pt'))
    if y11:
        TOP2_WEIGHTS['yolo11s'] = y11[0]
    if y8:
        TOP2_WEIGHTS['yolov8s'] = y8[0]

# Try 2: Direct lookup in raw mounted notebook outputs if zip didn't have them
if 'yolo11s' not in TOP2_WEIGHTS or not TOP2_WEIGHTS['yolo11s'].exists():
    for p in Path('/kaggle/input').rglob('best.pt'):
        p_str = str(p).lower()
        if 'yolo11s' in p_str and ('architecture2' in p_str or 'architecture-2' in p_str):
            TOP2_WEIGHTS['yolo11s'] = p
            break

if 'yolov8s' not in TOP2_WEIGHTS or not TOP2_WEIGHTS['yolov8s'].exists():
    for p in Path('/kaggle/input').rglob('best.pt'):
        p_str = str(p).lower()
        if 'yolov8s' in p_str and ('architecture1' in p_str or 'architecture-1' in p_str):
            TOP2_WEIGHTS['yolov8s'] = p
            break

# Print weights status
print('\n--- Top-2 Champion Weights Found ---')
for name, path in TOP2_WEIGHTS.items():
    mb = round(path.stat().st_size / (1024 * 1024), 2) if path.exists() else 0
    print(f'  - {name}: {path} (exists={path.exists()}, size={mb} MB)')
    if not path.exists():
        raise FileNotFoundError(f'Missing weights for {name}: {path}')

WORK_ROOT = Path('/kaggle/working/SHWD_STAGE2')
WORK_ROOT.mkdir(parents=True, exist_ok=True)
print('\n✅ Stage 2 Setup Initialized Successfully at WORK_ROOT =', WORK_ROOT)
# Out:
# 📌 DATASET_ROOT = /kaggle/input/datasets/hannhu4002/voc2028/VOC2028
# 📦 Found Compact ZIP at: /kaggle/input/notebooks/hannhu4002/shwd-baseline-consolidated-2/SHWD_Compact_Outputs.zip. Extracting...
# ✅ Extracted artifacts to: /kaggle/working/extracted_compact
# 📌 COMPACT_ROOT = /kaggle/working/extracted_compact
# 📌 SCRIPT_PATH = /kaggle/input/datasets/hannhu4002/shwd-benchmark-code/kaggle_shwd_baseline.py
# 📌 MODULE_PATH = /kaggle/input/datasets/hannhu4002/shwd-benchmark-code/custom_ablation_modules.py
# 📌 AUG_PATH = /kaggle/input/datasets/hannhu4002/shwd-benchmark-code/albumentations_hardcase_policy.py
#
# --- Top-2 Champion Weights Found ---
#   - yolo11s: /kaggle/working/extracted_compact/weights/yolo11s_best.pt (exists=True, size=18.28 MB)
#   - yolov8s: /kaggle/working/extracted_compact/weights/yolov8s_best.pt (exists=True, size=21.46 MB)
#
# ✅ Stage 2 Setup Initialized Successfully at WORK_ROOT = /kaggle/working/SHWD_STAGE2

# %%
# Step 3: Convert VOC2028 to YOLO format for Stage 2.
OUTPUT_DIR = Path('/kaggle/working/SHWD_YOLO_STAGE2')
if RUN_SETUP_CONVERT:
    cmd = [
        sys.executable, str(SCRIPT_PATH),
        '--mode', 'convert',
        '--dataset-root', str(DATASET_ROOT),
        '--output-dir', str(OUTPUT_DIR),
        '--overwrite',
    ]
    print('Executing command:', ' '.join(cmd))
    subprocess.run(cmd, check=True)
else:
    print('Skipping conversion because RUN_SETUP_CONVERT=False. Expected existing:', OUTPUT_DIR)
# Out:
# Executing command: /usr/bin/python3 /kaggle/input/datasets/hannhu4002/shwd-benchmark-code/kaggle_shwd_baseline.py --mode convert --dataset-root /kaggle/input/datasets/hannhu4002/voc2028/VOC2028 --output-dir /kaggle/working/SHWD_YOLO_STAGE2 --overwrite
# {
#   "dataset_root": "/kaggle/input/datasets/hannhu4002/voc2028/VOC2028",
#   "output_dir": "/kaggle/working/SHWD_YOLO_STAGE2",
#   "train_images": 6064,
#   "test_images": 1517,
#   "labels_written": 7581,
#   "missing_images": 0,
#   "missing_xml": 0,
#   "invalid_boxes": 0,
#   "ignored_objects": 3,
#   "class_counts": {
#     "hat": 9044,
#     "person": 111514
#   },
#   "ignored_by_class": {
#     "dog": 3
#   },
#   "dry_run": false
# }

# %%
# Step 4: Verify Conversion Report
import json

report_path = OUTPUT_DIR / 'conversion_report.json'
report = json.loads(report_path.read_text())
print(json.dumps(report, indent=2))
assert report['train_images'] == 6064, report['train_images']
assert report['test_images'] == 1517, report['test_images']
assert report['class_counts']['hat'] == 9044, report['class_counts']
assert report['class_counts']['person'] == 111514, report['class_counts']
assert report['ignored_by_class'].get('dog') == 3, report['ignored_by_class']
print('✅ Stage 2 dataset conversion verified successfully!')
# Out:
# {
#   "dataset_root": "/kaggle/input/datasets/hannhu4002/voc2028/VOC2028",
#   "output_dir": "/kaggle/working/SHWD_YOLO_STAGE2",
#   "train_images": 6064,
#   "test_images": 1517,
#   "labels_written": 7581,
#   "missing_images": 0,
#   "missing_xml": 0,
#   "invalid_boxes": 0,
#   "ignored_objects": 3,
#   "class_counts": {
#     "hat": 9044,
#     "person": 111514
#   },
#   "ignored_by_class": {
#     "dog": 3
#   },
#   "dry_run": false
# }
# ✅ Stage 2 dataset conversion verified successfully!

# %%
# Step 5: Copy Top-2 Weights to Working Directory
STAGE2_WEIGHTS = WORK_ROOT / 'weights'
STAGE2_WEIGHTS.mkdir(parents=True, exist_ok=True)
for name, src in TOP2_WEIGHTS.items():
    dst = STAGE2_WEIGHTS / src.name
    shutil.copy2(src, dst)
    print(f'Copied {name} -> {dst} ({round(dst.stat().st_size / (1024 * 1024), 2)} MB)')
# Out:
# Copied yolo11s -> /kaggle/working/SHWD_STAGE2/weights/yolo11s_best.pt (18.28 MB)
# Copied yolov8s -> /kaggle/working/SHWD_STAGE2/weights/yolov8s_best.pt (21.46 MB)

# %%
# Step 6: Smoke-Test Custom Modules under Kaggle PyTorch
if RUN_MODULE_SMOKE_TEST:
    cmd = [sys.executable, str(MODULE_PATH)]
    print('Running module test:', ' '.join(cmd))
    subprocess.run(cmd, check=True)
else:
    print('Skipping custom module smoke test because RUN_MODULE_SMOKE_TEST=False')
# Out:
# Running module test: /usr/bin/python3 /kaggle/input/datasets/hannhu4002/shwd-benchmark-code/custom_ablation_modules.py
# {'shape': (2, 24, 32, 32), 'repconv_fusion_max_diff': 2.1457672119140625e-06}
# {'focal_eiou': 0.20399829745292664}

# %%
# Step 7: Display Master Benchmark Leaderboard
import pandas as pd

csv_path = find_file_anywhere('master_benchmark_results.csv')
if csv_path and csv_path.exists():
    df = pd.read_csv(csv_path)
    cols = [c for c in ['model', 'map50', 'map50_95', 'ap50_hat', 'ap_hat', 'recall_hat', 'precision_hat', 'f1_hat', 'speed_inference_ms', 'onnx_latency_mean_ms', 'onnx_fps_mean', 'best_pt_mb'] if c in df.columns]
    print('🏆 Master Stage 1 Baseline Matrix:')
    display(df[cols].sort_values(['map50_95', 'map50'], ascending=False))
else:
    print('⚠️ Master CSV not found, setup ready for Stage 2 ablation training.')
# Out:
# 🏆 Master Stage 1 Baseline Matrix:
#          model     map50  map50_95  ap50_hat    ap_hat  recall_hat  \
# 0   yolo11s.pt  0.947379  0.625415  0.940598  0.742646    0.903456
# 1   yolov8s.pt  0.948927  0.622085  0.942811  0.737160    0.906199
# 2  yolov10s.pt  0.943913  0.621872  0.933565  0.734777    0.891388
# 3  yolov10n.pt  0.932999  0.603535  0.929662  0.718302    0.871340
# 4   yolov8n.pt  0.932052  0.602583  0.924177  0.718098    0.871640
# 5   yolo11n.pt  0.931852  0.602088  0.923260  0.715203    0.865058
#
#    precision_hat    f1_hat  speed_inference_ms  onnx_latency_mean_ms  \
# 0       0.911165  0.907294            6.524133              144.5346
# 1       0.917859  0.911991            6.105510              187.6546
# 2       0.918822  0.904897            6.227032              147.7368
# 3       0.915824  0.893028            2.663596               90.6514
# 4       0.904821  0.887921            2.855711               63.4755
# 5       0.930009  0.896358            3.182678               68.2158
#
#    onnx_fps_mean  best_pt_mb
# 0           6.92      18.278
# 1           5.33      21.465
# 2           6.77      15.749
# 3          11.03       5.475
# 4          15.75       5.949
# 5          14.66       5.207

# %% [markdown]
# ## Next Execution Step: Stage 2 Custom Ablation Experiments
#
# After this setup notebook passes, begin custom ablation training using **`yolo11s_best.pt`** and **`yolov8s_best.pt`** as controls.
#
# **Ablation Progression:**
# 1. **A0**: Re-evaluate `yolo11s_best.pt` & `yolov8s_best.pt` as control baselines.
# 2. **A1**: Apply hard-case online augmentation (Albumentations: RandomShadow, HSV shift, Cutout).
# 3. **A2**: Inject **CoordConv** in stem/neck.
# 4. **A3**: Inject **RepConv / RepC3** and verify `switch_to_deploy()` fusion.
# 5. **A4**: Apply **Focal-EIoU Loss** for bounding box regression + alpha-focal classification for `hat`.
# 6. **A5**: Inject **BiFormer Attention** if small/occluded helmets require fine-grained routing.
# 7. **A6**: Train final combined candidate.

# %% [markdown]
# ## Stage 2 Runner Cells
#
# The following cells make the setup notebook usable like Stage 1: you can toggle A0/A1 from the settings block. A2-A6 remain guarded because they require patching architecture/loss into a custom trainer, not just changing a stock Ultralytics training flag.

# %%
# Step 8: A0 Control Evaluation
# Re-evaluate the selected top-2 weights on the Stage 2 YOLO dataset.
if RUN_A0_CONTROL_EVAL:
    from ultralytics import YOLO
    import csv
    import json

    a0_dir = WORK_ROOT / 'A0_control_eval'
    a0_dir.mkdir(parents=True, exist_ok=True)
    rows = []

    for name in STAGE2_BACKBONES:
        weight = TOP2_WEIGHTS[name]
        print(f'\n[A0] Evaluating {name}: {weight}')
        model = YOLO(str(weight))
        metrics = model.val(
            data=str(OUTPUT_DIR / 'shwd.yaml'),
            imgsz=STAGE2_IMGSZ,
            device=STAGE2_EVAL_DEVICE,
            split='val',
            plots=True,
            project=str(a0_dir),
            name=name,
            exist_ok=True,
        )

        row = {
            'ablation_id': 'A0_control',
            'model': name,
            'weight': str(weight),
            'map50': getattr(metrics.box, 'map50', None),
            'map50_95': getattr(metrics.box, 'map', None),
            'map75': getattr(metrics.box, 'map75', None),
        }
        maps = getattr(metrics.box, 'maps', None)
        if maps is not None and len(maps) >= 2:
            row['ap_hat'] = float(maps[0])
            row['ap_person'] = float(maps[1])
        rows.append(row)
        print(row)

    out_csv = a0_dir / 'A0_control_results.csv'
    with out_csv.open('w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=sorted({k for r in rows for k in r.keys()}))
        writer.writeheader()
        writer.writerows(rows)
    print('Saved:', out_csv)
else:
    print('Skipping A0 because RUN_A0_CONTROL_EVAL=False and RUN_STAGE2_FULL=False')
# Out:
# Skipping A0 because RUN_A0_CONTROL_EVAL=False and RUN_STAGE2_FULL=False

# %%
# Step 9: A1 Build Offline Albumentations Hard-Case Dataset
# This creates a train set containing original train images plus augmented copies.
# It is disabled by default because full offline augmentation writes many images to /kaggle/working.
if RUN_A1_BUILD_AUG_DATASET:
    import cv2
    import shutil
    import sys
    from tqdm.auto import tqdm

    module_dir = Path(AUG_PATH).parent
    if str(module_dir) not in sys.path:
        sys.path.insert(0, str(module_dir))
    from albumentations_hardcase_policy import augment_one_yolo_sample

    A1_DIR = Path('/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG')
    for sub in ['images/train', 'labels/train', 'images/test', 'labels/test']:
        (A1_DIR / sub).mkdir(parents=True, exist_ok=True)

    def safe_link_or_copy(src, dst):
        dst = Path(dst)
        dst.parent.mkdir(parents=True, exist_ok=True)
        if dst.exists() or dst.is_symlink():
            return
        try:
            os.symlink(src, dst)
        except OSError:
            shutil.copy2(src, dst)

    # Link/copy original train and test files.
    for split in ['train', 'test']:
        for img in (OUTPUT_DIR / 'images' / split).glob('*'):
            safe_link_or_copy(img, A1_DIR / 'images' / split / img.name)
        for lab in (OUTPUT_DIR / 'labels' / split).glob('*.txt'):
            shutil.copy2(lab, A1_DIR / 'labels' / split / lab.name)

    train_images = sorted((OUTPUT_DIR / 'images/train').glob('*'))
    if A1_AUGMENT_LIMIT is not None:
        train_images = train_images[:A1_AUGMENT_LIMIT]
    print(f'[A1] Building augmented copies for {len(train_images)} train images')

    ok = 0
    for img in tqdm(train_images):
        stem = img.stem
        label = OUTPUT_DIR / 'labels/train' / f'{stem}.txt'
        out_img = A1_DIR / 'images/train' / f'{stem}_hardaug.jpg'
        out_lab = A1_DIR / 'labels/train' / f'{stem}_hardaug.txt'
        if augment_one_yolo_sample(img, label, out_img, out_lab, image_size=STAGE2_IMGSZ):
            ok += 1
    print(f'[A1] Augmented images written: {ok}')

    yaml_text = '\n'.join([
        f'path: {A1_DIR.as_posix()}',
        'train: images/train',
        'val: images/test',
        'test: images/test',
        'nc: 2',
        'names:',
        '  0: hat',
        '  1: person',
        '',
    ])
    (A1_DIR / 'shwd_a1_hardaug.yaml').write_text(yaml_text, encoding='utf-8')
    print('A1 YAML:', A1_DIR / 'shwd_a1_hardaug.yaml')
else:
    print('Skipping A1 dataset build because RUN_A1_BUILD_AUG_DATASET=False')
# Out:
# [A1] Building augmented copies for 6064 train images
#   0%|          | 0/6064 [00:00<?, ?it/s]
# [A1] Augmented images written: 6064
# A1 YAML: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/shwd_a1_hardaug.yaml

# %%
# Step 10: A1 Hard-Case Augmentation Fine-Tuning
# Starts from yolo11s_best.pt and yolov8s_best.pt, then fine-tunes on the A1 augmented dataset.
if RUN_A1_HARDCASE_AUG_TRAIN:
    from ultralytics import YOLO

    A1_DIR = Path('/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG')
    A1_YAML = A1_DIR / 'shwd_a1_hardaug.yaml'
    if not A1_YAML.exists():
        raise FileNotFoundError('Run Step 9 with RUN_A1_BUILD_AUG_DATASET=True before A1 training.')

    epochs = STAGE2_FULL_EPOCHS if RUN_STAGE2_FULL else STAGE2_SMOKE_EPOCHS
    for name in STAGE2_BACKBONES:
        weight = TOP2_WEIGHTS[name]
        print(f'\n[A1] Fine-tuning {name} for {epochs} epochs from {weight}')
        model = YOLO(str(weight))
        model.train(
            data=str(A1_YAML),
            epochs=epochs,
            imgsz=STAGE2_IMGSZ,
            batch=STAGE2_BATCH,
            device=STAGE2_DEVICE,
            workers=STAGE2_WORKERS,
            patience=STAGE2_PATIENCE,
            seed=STAGE2_SEED,
            deterministic=True,
            project=str(WORK_ROOT / 'A1_hardcase_aug_train'),
            name=name,
            exist_ok=True,
            save=True,
            save_period=-1,
            cache=False,
            plots=True,
            hsv_h=0.025,
            hsv_s=0.75,
            hsv_v=0.45,
            translate=0.10,
            scale=0.50,
            fliplr=0.50,
            mosaic=1.00,
            mixup=0.10,
            close_mosaic=10,
        )
else:
    print('Skipping A1 training because RUN_A1_HARDCASE_AUG_TRAIN=False and RUN_STAGE2_FULL=False')
# Out:
# Skipping A1 training because RUN_A1_HARDCASE_AUG_TRAIN=False and RUN_STAGE2_FULL=False

# %% [markdown]
# ## Step 11: A2 CoordConv Fine-Tuning
#
# This cell fine-tunes the Top-2 backbones (`yolo11s`, `yolov8s`) by replacing the standard Conv stem with a **`CoordConv`** module.
# It appends normalized spatial $x$ and $y$ coordinate channels to the input image tensor before convolution, allowing the model to distinguish ground-level distractors (e.g. yellow buckets, traffic cones) from helmets worn on heads.

# %%
# Step 11: A2 CoordConv Fine-Tuning
if RUN_A2_COORDCONV:
    from ultralytics import YOLO
    import sys
    import os
    import site
    from pathlib import Path
    import torch
    import torch.nn as nn

    # Ensure custom_ablation_modules is importable
    module_dir = Path(MODULE_PATH).parent
    if str(module_dir) not in sys.path:
        sys.path.insert(0, str(module_dir))
    from custom_ablation_modules import CoordConv

    # Write ablation_trainer.py into site-packages and working dir so PyTorch DDP subprocesses can import it natively on all GPUs
    trainer_code = (
        'from ultralytics.models.yolo.detect import DetectionTrainer\n\n'
        'class AblationTrainer(DetectionTrainer):\n'
        '    def get_model(self, cfg=None, weights=None, verbose=True):\n'
        '        return getattr(self, "patched_model", super().get_model(cfg, weights, verbose))\n'
    )

    # 1. Write to /kaggle/working/ablation_trainer.py
    work_dir = '/kaggle/working'
    (Path(work_dir) / 'ablation_trainer.py').write_text(trainer_code, encoding='utf-8')
    if work_dir not in sys.path:
        sys.path.insert(0, work_dir)

    # 2. Write to Python site-packages (globally importable by all DDP rank subprocesses)
    for sp in site.getsitepackages():
        try:
            (Path(sp) / 'ablation_trainer.py').write_text(trainer_code, encoding='utf-8')
        except Exception:
            pass

    # 3. Export PYTHONPATH to environment for DDP launcher
    existing_pp = os.environ.get('PYTHONPATH', '')
    if work_dir not in existing_pp:
        os.environ['PYTHONPATH'] = f"{work_dir}:{existing_pp}" if existing_pp else work_dir

    from ablation_trainer import AblationTrainer

    # Check dataset: Prefer A1 augmented dataset to preserve cumulative progression (Data Aug + CoordConv)
    A1_DIR = Path('/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG')
    A1_YAML = A1_DIR / 'shwd_a1_hardaug.yaml'
    if A1_YAML.exists():
        data_yaml = A1_YAML
        print(f'[A2 CoordConv] Cumulative Mode: Training on A1 Hard-Case Augmented dataset ({data_yaml})')
    else:
        data_yaml = OUTPUT_DIR / 'shwd.yaml'
        print(f'[A2 CoordConv] Standard Mode: Training on Stage 2 dataset ({data_yaml})')

    epochs = STAGE2_FULL_EPOCHS if RUN_STAGE2_FULL else STAGE2_SMOKE_EPOCHS

    for name in STAGE2_BACKBONES:
        weight = TOP2_WEIGHTS[name]
        print(f'\n[A2 CoordConv] Patching stem & fine-tuning {name} for {epochs} epochs from {weight} on Dual GPU ({STAGE2_DEVICE})')
        base_model = YOLO(str(weight))

        # Patch Stem layer 0 with CoordConv
        stem = base_model.model.model[0]
        c1 = 3
        c2 = stem.conv.out_channels
        k = stem.conv.kernel_size[0] if hasattr(stem.conv, 'kernel_size') else 3
        s = stem.conv.stride[0] if hasattr(stem.conv, 'stride') else 2

        coord_stem = CoordConv(c1=c1, c2=c2, k=k, s=s)
        coord_stem.i = getattr(stem, 'i', 0)
        coord_stem.f = getattr(stem, 'f', -1)
        coord_stem.type = 'CoordConv'
        base_model.model.model[0] = coord_stem

        # Configure AblationTrainer overrides for Dual GPU DDP
        overrides = {
            'model': str(weight),
            'data': str(data_yaml),
            'epochs': epochs,
            'imgsz': STAGE2_IMGSZ,
            'batch': STAGE2_BATCH,
            'device': STAGE2_DEVICE,
            'workers': STAGE2_WORKERS,
            'patience': STAGE2_PATIENCE,
            'seed': STAGE2_SEED,
            'deterministic': True,
            'project': str(WORK_ROOT / 'A2_coordconv_train'),
            'name': name,
            'exist_ok': True,
            'save': True,
            'save_period': -1,
            'cache': False,
            'plots': True,
        }

        trainer = AblationTrainer(overrides=overrides)
        trainer.patched_model = base_model.model
        trainer.train()
else:
    print('Skipping A2 CoordConv training because RUN_A2_COORDCONV=False')
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# [A2 CoordConv] Cumulative Mode: Training on A1 Hard-Case Augmented dataset (/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/shwd_a1_hardaug.yaml)
#
# [A2 CoordConv] Patching stem & fine-tuning yolo11s for 100 epochs from /kaggle/working/extracted_compact/weights/yolo11s_best.pt on Dual GPU (0,1)
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
#                                                         CUDA:1 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/shwd_a1_hardaug.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/working/extracted_compact/weights/yolo11s_best.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11s, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/SHWD_STAGE2/A2_coordconv_train, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/SHWD_STAGE2/A2_coordconv_train/yolo11s, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=3407, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.9MB/s 0.0s
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 19847 /root/.config/Ultralytics/DDP/_temp_9uoubye3136909554786880.py
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
#                                                         CUDA:1 (Tesla T4, 14912MiB)
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 66.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1304.5±1064.7 MB/s, size: 112.0 KB)
# train: Scanning /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/labels/train... 12075 images, 5 backgrounds, 53 corrupt: 100% ━━━━━━━━━━━━ 12128/12128 1.2Kit/s 10.3s
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000003.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000003.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000006.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000006.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000007.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000007.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000011.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000011.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000061.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000061.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000068.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000068.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000091.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000091.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000113.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000113.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000153.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000153.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000158.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000158.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000173.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000173.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000177.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000177.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000184.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000184.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000226.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000226.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000267.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000267.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000268.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000268.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000274.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000274.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000284.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000284.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000290.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000290.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000320.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000320.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000393.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000393.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000397.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000397.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000433.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000433.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000458.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000458.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000512.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000512.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000514.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000514.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000528.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000528.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000548.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000548.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000601.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000601.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000686.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000686.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000687.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000687.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000734.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000734.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000738.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000738.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000797.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000797.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000798.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000798.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000799.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000799.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000820.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000820.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000827.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000827.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000909.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000909.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000964.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000964.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000985.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/000985.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001042.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001042.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001046.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001046.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001150.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001150.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001354.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001354.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001358.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001358.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001386.JPG: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001386.JPG'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001387.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/001387.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_000609.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_000609.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_000878.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_000878.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_001057.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_001057.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_001363.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_001363.jpg'
# train: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_001696.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/train/part2_001696.jpg'
# train: New cache created: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 25.5±12.6 MB/s, size: 100.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/labels/test... 1506 images, 0 backgrounds, 11 corrupt: 100% ━━━━━━━━━━━━ 1517/1517 539.5it/s 2.8s
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000002.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000002.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000106.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000106.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000168.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000168.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000291.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000291.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000457.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000457.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000565.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000565.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000599.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000599.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000640.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000640.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000796.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000796.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000815.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/000815.jpg'
# val: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/part2_001825.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/images/test/part2_001825.jpg'
# val: New cache created: /kaggle/working/SHWD_YOLO_STAGE2_A1_HARD_AUG/labels/test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/SHWD_STAGE2/A2_coordconv_train/yolo11s/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/SHWD_STAGE2/A2_coordconv_train/yolo11s
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       2.6G      1.373     0.5851     0.9588         91        640: 100% ━━━━━━━━━━━━ 755/755 3.6it/s 3:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 1.7it/s 28.2s
#                    all       1506      24375      0.912      0.902      0.942      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.88G      1.389     0.6074     0.9617        100        640: 100% ━━━━━━━━━━━━ 755/755 4.4it/s 2:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.8s
#                    all       1506      24375       0.92      0.893      0.937      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.88G      1.418     0.6286     0.9735        150        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.916      0.881      0.934        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.88G      1.432     0.6397     0.9786        107        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.914      0.875      0.931      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.88G      1.432     0.6386     0.9778        210        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.921      0.878      0.932      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.88G       1.43     0.6312     0.9763        281        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.4s
#                    all       1506      24375       0.92      0.876      0.933      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.88G      1.419     0.6288     0.9765         79        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:45
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.925      0.884      0.934        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.88G      1.427       0.63      0.977        119        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.925      0.885      0.935      0.601
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.88G      1.409     0.6207     0.9769        178        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.8s
#                    all       1506      24375      0.923      0.884      0.937        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.88G      1.403     0.6177     0.9751        280        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375      0.927      0.884      0.934      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.88G      1.401     0.6166     0.9754        143        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375      0.925      0.892      0.941      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.88G      1.412     0.6129     0.9725         69        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375      0.924      0.885      0.936      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.88G      1.407     0.6095     0.9715        135        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.6it/s 8.6s
#                    all       1506      24375      0.919      0.889      0.938      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.88G      1.398      0.605      0.968         57        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.8s
#                    all       1506      24375      0.924      0.883      0.937      0.601
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.88G      1.398     0.6088     0.9698         90        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375      0.921       0.89       0.94      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.88G      1.399     0.6081     0.9677        207        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.4s
#                    all       1506      24375       0.93      0.892      0.943      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.88G      1.393     0.6012     0.9682        126        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.928       0.89       0.94      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.88G       1.38     0.5945     0.9666        254        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.926      0.893      0.941      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.88G       1.39     0.5951     0.9653        114        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.927      0.893       0.94       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.88G      1.389     0.5953     0.9619        154        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.922      0.893      0.941      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.88G      1.382     0.5941     0.9614         95        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375      0.924      0.896       0.94      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.88G      1.389     0.5934     0.9671        117        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.5it/s 8.8s
#                    all       1506      24375       0.93      0.896      0.941      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.88G      1.369     0.5857     0.9605        256        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.9s
#                    all       1506      24375      0.926      0.896      0.943      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.88G      1.391      0.592     0.9604        180        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375      0.924      0.894      0.941      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.88G      1.381     0.5916     0.9583         99        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.9s
#                    all       1506      24375      0.926      0.896      0.943      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.88G      1.388     0.5876     0.9582         97        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.8s
#                    all       1506      24375      0.924      0.896      0.941      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.88G      1.375     0.5874     0.9602         50        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.8s
#                    all       1506      24375      0.929      0.895      0.941      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.88G      1.371     0.5821     0.9551        128        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375       0.93      0.897      0.943      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.88G      1.363      0.579     0.9567        192        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.8s
#                    all       1506      24375      0.932      0.892      0.943      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.88G      1.359     0.5776     0.9543        247        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.5it/s 8.8s
#                    all       1506      24375       0.93      0.899      0.944      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.88G      1.357     0.5721     0.9541        180        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.9s
#                    all       1506      24375      0.929      0.904      0.945      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.88G      1.357     0.5752     0.9545        145        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 9.0s
#                    all       1506      24375      0.929      0.898      0.942      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.88G      1.354     0.5703     0.9546        158        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.9s
#                    all       1506      24375      0.928      0.903      0.945      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.88G      1.349     0.5725      0.955         53        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.6it/s 8.6s
#                    all       1506      24375      0.933      0.902      0.945      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.88G      1.361      0.572     0.9519         75        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.9s
#                    all       1506      24375      0.933        0.9      0.945      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.88G      1.364     0.5753     0.9505         26        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.935      0.899      0.945      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.88G       1.35     0.5707     0.9522         40        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375      0.933      0.903      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.88G      1.346     0.5671     0.9505        261        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.931      0.903      0.945      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.88G      1.338     0.5612     0.9493         84        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.928      0.904      0.945      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.88G      1.333     0.5607     0.9489        105        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.5it/s 8.8s
#                    all       1506      24375      0.931      0.904      0.946      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.88G      1.331     0.5604     0.9466         54        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 9.0s
#                    all       1506      24375      0.926      0.908      0.946      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.88G      1.328     0.5582     0.9493        121        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375      0.931      0.903      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.88G      1.338     0.5557     0.9437        283        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.5it/s 8.8s
#                    all       1506      24375      0.929      0.907      0.946       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.88G      1.322     0.5538     0.9444        364        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.934      0.903      0.945      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      3.04G      1.326     0.5533     0.9441        117        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.6s
#                    all       1506      24375      0.935      0.902      0.946      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      3.04G      1.321     0.5511     0.9449         35        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 9.0s
#                    all       1506      24375      0.929      0.907      0.944       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      3.04G      1.311      0.548     0.9459        186        640: 100% ━━━━━━━━━━━━ 755/755 4.5it/s 2:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.1s
#                    all       1506      24375      0.927      0.905      0.946      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.04G      1.322     0.5517     0.9419        123        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375      0.932      0.901      0.946      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      3.04G      1.312      0.547      0.946         70        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375      0.929      0.904      0.947      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.04G      1.302     0.5455     0.9403        154        640: 100% ━━━━━━━━━━━━ 755/755 4.6it/s 2:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375       0.93      0.906      0.948      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.04G      1.306     0.5435     0.9399        108        640: 100% ━━━━━━━━━━━━ 755/755 4.5it/s 2:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.8it/s 10.0s
#                    all       1506      24375      0.932      0.906      0.948       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.04G      1.301     0.5403      0.936         52        640: 100% ━━━━━━━━━━━━ 755/755 4.5it/s 2:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 8.9s
#                    all       1506      24375      0.933      0.906      0.948       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.04G      1.307     0.5447     0.9371        218        640: 100% ━━━━━━━━━━━━ 755/755 4.5it/s 2:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.931      0.905      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      3.04G      1.306     0.5415     0.9374         88        640: 100% ━━━━━━━━━━━━ 755/755 4.5it/s 2:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.6s
#                    all       1506      24375      0.939      0.897      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.04G       1.31     0.5409     0.9403         39        640: 100% ━━━━━━━━━━━━ 755/755 4.5it/s 2:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.4s
#                    all       1506      24375      0.935        0.9      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.04G      1.299     0.5371     0.9348        311        640: 100% ━━━━━━━━━━━━ 755/755 4.5it/s 2:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.8it/s 10.0s
#                    all       1506      24375      0.938        0.9      0.947       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.04G      1.303     0.5378     0.9347        153        640: 100% ━━━━━━━━━━━━ 755/755 4.5it/s 2:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.7s
#                    all       1506      24375      0.938      0.899      0.944       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.04G       1.29     0.5342     0.9337         50        640: 100% ━━━━━━━━━━━━ 755/755 4.4it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.7it/s 10.1s
#                    all       1506      24375      0.935      0.903      0.945      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.04G      1.286     0.5308     0.9344         43        640: 100% ━━━━━━━━━━━━ 755/755 4.4it/s 2:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.5s
#                    all       1506      24375      0.936      0.902      0.947       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.04G      1.284     0.5353     0.9303        204        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.4it/s 10.9s
#                    all       1506      24375      0.935      0.903      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.04G      1.275     0.5255     0.9307        149        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.6s
#                    all       1506      24375      0.931      0.906      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.04G      1.279      0.527     0.9292         88        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.7it/s 10.2s
#                    all       1506      24375      0.932      0.908      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      3.04G      1.265      0.524     0.9307         93        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.7s
#                    all       1506      24375      0.931       0.91      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      3.04G      1.271     0.5264     0.9309        159        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.7it/s 10.2s
#                    all       1506      24375      0.934      0.906      0.946      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      3.04G      1.263     0.5203     0.9285         84        640: 100% ━━━━━━━━━━━━ 755/755 4.4it/s 2:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.6s
#                    all       1506      24375      0.932      0.908      0.944       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.04G      1.254      0.519     0.9274        107        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.6it/s 10.5s
#                    all       1506      24375      0.931       0.91      0.946       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      3.04G      1.261     0.5209     0.9266        168        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.7s
#                    all       1506      24375      0.933      0.906      0.944       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.04G      1.253     0.5166      0.927         93        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.7it/s 10.3s
#                    all       1506      24375      0.931      0.908      0.945      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      3.04G      1.256     0.5196     0.9249        101        640: 100% ━━━━━━━━━━━━ 755/755 4.4it/s 2:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.7s
#                    all       1506      24375      0.933      0.907      0.945      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.04G      1.247     0.5141     0.9228        183        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.6s
#                    all       1506      24375      0.933      0.907      0.944      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      3.04G      1.241     0.5123     0.9244        128        640: 100% ━━━━━━━━━━━━ 755/755 4.3it/s 2:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.9it/s 9.8s
#                    all       1506      24375      0.933      0.907      0.944      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#      65/100      2.93G      1.233     0.5084     0.9192         84        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.6it/s 10.4s
#                    all       1506      24375      0.924      0.913      0.944      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.93G      1.224     0.5057     0.9184        107        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.929      0.909      0.944      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.93G      1.231     0.5071      0.918        168        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375      0.929      0.909      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.93G      1.223     0.5036     0.9172         93        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.4s
#                    all       1506      24375      0.931       0.91      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.93G      1.227     0.5049      0.916        101        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.933      0.912      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.93G       1.22      0.501     0.9146        183        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.3it/s 11.2s
#                    all       1506      24375      0.935      0.909      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.93G      1.213     0.4998     0.9155        128        640: 100% ━━━━━━━━━━━━ 755/755 4.9it/s 2:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.932      0.911      0.944      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.93G      1.226     0.5034     0.9155        185        640: 100% ━━━━━━━━━━━━ 755/755 4.9it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.5it/s 8.7s
#                    all       1506      24375      0.932      0.911      0.944      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.93G       1.22     0.5017     0.9123        137        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.4it/s 9.0s
#                    all       1506      24375      0.933      0.911      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.93G      1.203     0.4929      0.911        359        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375       0.93      0.912      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.93G      1.198     0.4916     0.9102        146        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.9it/s 9.7s
#                    all       1506      24375       0.93      0.913      0.945      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.93G      1.191      0.489     0.9098         79        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375       0.93      0.912      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.93G      1.206     0.4942     0.9065        271        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.3s
#                    all       1506      24375      0.929      0.912      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.93G      1.185     0.4857     0.9076        147        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.9it/s 9.9s
#                    all       1506      24375       0.93      0.911      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.93G      1.181     0.4834     0.9069        170        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375      0.928      0.912      0.944      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.93G      1.189     0.4884      0.907        209        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.932       0.91      0.944      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.93G      1.191     0.4856      0.905        134        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.933      0.909      0.944      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.93G      1.188     0.4855     0.9046        231        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.6s
#                    all       1506      24375      0.933      0.909      0.944      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.93G      1.188     0.4837     0.9061        232        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.3it/s 11.3s
#                    all       1506      24375      0.934      0.908      0.944      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.93G      1.178     0.4803     0.9025         39        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.3s
#                    all       1506      24375      0.933      0.908      0.944      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100       3.1G      1.179     0.4811     0.9018         97        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.3s
#                    all       1506      24375      0.934      0.907      0.944      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100       3.1G      1.169     0.4762     0.9024        192        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.8it/s 10.0s
#                    all       1506      24375      0.934      0.906      0.944      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100       3.1G      1.175      0.478     0.9012        166        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.1s
#                    all       1506      24375      0.934      0.906      0.944      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100       3.1G      1.168      0.474     0.9005        148        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.6it/s 10.3s
#                    all       1506      24375      0.931       0.91      0.944      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100       3.1G      1.158     0.4721     0.8995        140        640: 100% ━━━━━━━━━━━━ 755/755 4.7it/s 2:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.6s
#                    all       1506      24375       0.93      0.911      0.943      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100       3.1G      1.164     0.4729     0.8996        137        640: 100% ━━━━━━━━━━━━ 755/755 4.8it/s 2:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.7s
#                    all       1506      24375      0.927      0.912      0.944      0.611
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100       3.1G      1.133      0.446     0.8932         47        640: 100% ━━━━━━━━━━━━ 755/755 5.0it/s 2:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.5it/s 10.6s
#                    all       1506      24375      0.927      0.913      0.943      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100       3.1G      1.124     0.4414     0.8912         47        640: 100% ━━━━━━━━━━━━ 755/755 5.1it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375      0.929      0.911      0.943      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100       3.1G      1.124     0.4409     0.8912         94        640: 100% ━━━━━━━━━━━━ 755/755 5.1it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.4s
#                    all       1506      24375      0.928      0.911      0.943      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100       3.1G      1.115     0.4385     0.8875        189        640: 100% ━━━━━━━━━━━━ 755/755 5.1it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.1it/s 9.4s
#                    all       1506      24375      0.929      0.911      0.943      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100       3.1G      1.103     0.4347     0.8872        105        640: 100% ━━━━━━━━━━━━ 755/755 5.1it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.5it/s 10.8s
#                    all       1506      24375      0.928      0.912      0.943       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100       3.1G      1.104      0.433     0.8859         50        640: 100% ━━━━━━━━━━━━ 755/755 5.2it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.0s
#                    all       1506      24375      0.928      0.912      0.943       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100       3.1G       1.11     0.4355     0.8891        162        640: 100% ━━━━━━━━━━━━ 755/755 5.2it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.3it/s 9.1s
#                    all       1506      24375      0.926      0.913      0.943       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100       3.1G      1.102     0.4342     0.8851         40        640: 100% ━━━━━━━━━━━━ 755/755 5.1it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.3s
#                    all       1506      24375      0.926      0.913      0.943       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100       3.1G      1.106     0.4325     0.8858          7        640: 100% ━━━━━━━━━━━━ 755/755 5.2it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.2it/s 9.2s
#                    all       1506      24375      0.926      0.913      0.943       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100       3.1G      1.099     0.4314     0.8861        116        640: 100% ━━━━━━━━━━━━ 755/755 5.1it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 5.0it/s 9.6s
#                    all       1506      24375      0.927      0.912      0.943       0.61
#
# 100 epochs completed in 4.664 hours.
# Optimizer stripped from /kaggle/working/SHWD_STAGE2/A2_coordconv_train/yolov8s/weights/last.pt, 22.5MB
# Optimizer stripped from /kaggle/working/SHWD_STAGE2/A2_coordconv_train/yolov8s/weights/best.pt, 22.5MB
#
# Validating /kaggle/working/SHWD_STAGE2/A2_coordconv_train/yolov8s/weights/best.pt...
# Model summary (fused): 73 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 48/48 4.1it/s 11.7s
#                    all       1506      24375      0.929       0.91      0.946      0.615
#                    hat        652       1823      0.922        0.9      0.938       0.73
#                 person        944      22552      0.936       0.92      0.954        0.5
# Speed: 0.1ms preprocess, 1.7ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/SHWD_STAGE2/A2_coordconv_train/yolov8s

# %% [markdown]
# ## Step 12: Package Stage 2 Compact Outputs ZIP Archive
#
# This cell automatically packages ONLY the essential Stage 2 artifacts (`best.pt` weights, CSV result logs, PR curves, confusion matrices) into a single lightweight ZIP archive (`SHWD_Stage2_Outputs_Compact.zip`).
#
# It skips all converted dataset images, text labels, `.cache` files, and intermediate checkpoints, allowing you to download your Stage 2 outputs from Kaggle in under 5 seconds with ZERO network dropouts!

# %%
# Step 12: Package Stage 2 Compact Outputs ZIP
import zipfile
from pathlib import Path

zip_name = "SHWD_Stage2_Outputs_Compact.zip"
zip_path = Path("/kaggle/working") / zip_name
print(f"📦 Packaging Stage 2 Compact ZIP: {zip_path}")

collected_files = []

# 1. Collect all CSV results under WORK_ROOT preserving relative model paths
if WORK_ROOT.exists():
    for csv_file in WORK_ROOT.rglob("*.csv"):
        rel_path = csv_file.relative_to(WORK_ROOT)
        collected_files.append((csv_file, f"csv_results/{rel_path.as_posix().replace('/', '_')}"))

# 2. Collect best.pt weights from Stage 2 ablation runs
if WORK_ROOT.exists():
    for pt in WORK_ROOT.rglob("best.pt"):
        run_name = pt.parent.parent.name
        arc_name = f"weights/{run_name}_best.pt"
        collected_files.append((pt, arc_name))
        print(f"  [Collected Weight] {run_name} -> {arc_name} ({round(pt.stat().st_size / (1024*1024), 2)} MB)")

# 3. Collect Evaluation Plots (PR curves, confusion matrices, results.png)
if WORK_ROOT.exists():
    for img in WORK_ROOT.rglob("*.png"):
        rel_path = img.relative_to(WORK_ROOT)
        collected_files.append((img, f"eval_plots/{rel_path.as_posix()}"))

# 4. Build the ZIP archive
with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as zip_out:
    for src, arc in collected_files:
        if src.exists():
            zip_out.write(src, arcname=arc)

zip_size_mb = round(zip_path.stat().st_size / (1024 * 1024), 2) if zip_path.exists() else 0
print("========================================================================")
print(f"🎉 SUCCESS! Created Stage 2 Compact ZIP: {zip_path}")
print(f"📦 Archive Size: {zip_size_mb} MB")
print("🚀 Click and download 'SHWD_Stage2_Outputs_Compact.zip' from Kaggle Output")
print("   in under 5 seconds with ZERO network interruptions!")
print("========================================================================")
# Out:
# 📦 Packaging Stage 2 Compact ZIP: /kaggle/working/SHWD_Stage2_Outputs_Compact.zip
#   [Collected Weight] yolo11s -> weights/yolo11s_best.pt (18.28 MB)
#   [Collected Weight] yolov8s -> weights/yolov8s_best.pt (21.47 MB)
# ========================================================================
# 🎉 SUCCESS! Created Stage 2 Compact ZIP: /kaggle/working/SHWD_Stage2_Outputs_Compact.zip
# 📦 Archive Size: 38.35 MB
# 🚀 Click and download 'SHWD_Stage2_Outputs_Compact.zip' from Kaggle Output
#    in under 5 seconds with ZERO network interruptions!
# ========================================================================
